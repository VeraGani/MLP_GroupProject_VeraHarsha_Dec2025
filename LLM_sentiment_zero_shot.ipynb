# %%
# Mount Google Drive to save/load files from Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone the LLM-Sentiment GitHub repo and change directory into it
import os

repo_path = "/content/LLM-Sentiment"

if not os.path.exists(repo_path):
    print("Folder does NOT exist — cloning the repo...")
    # !git clone https://github.com/DAMO-NLP-SG/LLM-Sentiment.git
else:
    print("Folder already exists. Skipping clone.")

# %cd /content/LLM-Sentiment
# !ls
# Out:
# Folder does NOT exist — cloning the repo...
# Cloning into 'LLM-Sentiment'...
# remote: Enumerating objects: 621, done.
# remote: Counting objects: 100% (621/621), done.
# remote: Compressing objects: 100% (363/363), done.
# remote: Total 621 (delta 27), reused 613 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (621/621), 1.32 MiB | 19.09 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/LLM-Sentiment
# data  evaluate.py  LICENSE  predict.py	README.md  requirements.txt  script

# %%
# Upgrade pip
# !pip install -q --upgrade pip

# Install the old OpenAI client and other useful libraries required by code
# !pip install -q \
  "openai==0.27.2" \
  "tqdm>=4.65" \
  "tenacity>=8.2.2" \
  "numpy>=1.24" \
  "pandas>=2.0" \
  "scikit-learn>=1.4" \
  "transformers>=4.36" \
  "torch>=2.0"

import openai
import numpy as np
import pandas as pd
import sklearn
import torch
import transformers

print("Packages installed and imported ✔️")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.6 MB/s eta 0:00:00
# Packages installed and imported ✔️

# %%
# Configure the OpenAI API key in the environment and test one simple API call
import os
import openai

os.environ["OPENAI_API_KEY"] = "API key deleted for safety reasons before comitting to GitHub"

# Quick test using the old API style to make sure it works
openai.api_key = os.environ["OPENAI_API_KEY"]

resp = openai.ChatCompletion.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Hello from Colab"}]
)
print(resp["choices"][0]["message"]["content"])
# Out:
# Hello! How can I assist you today with Google Colab? If you have any questions or need help with a specific task, feel free to ask!

# %%
# Run the zero-shot experiment script from the original paper to generate model predictions
# %cd /content/LLM-Sentiment

# !bash script/run_zero_shot.sh
# Out:
# /content/LLM-Sentiment
# Predict on Task: sc, Dataset: asc_lap14
# Processing asc_lap14: 100% 500/500 [02:25<00:00,  3.45it/s]
# Predict on Task: sc, Dataset: asc_rest14
# Processing asc_rest14: 100% 500/500 [02:32<00:00,  3.27it/s]
# Predict on Task: sc, Dataset: imdb
# Processing imdb: 100% 500/500 [02:40<00:00,  3.11it/s]
# Predict on Task: sc, Dataset: mr
# Processing mr: 100% 500/500 [02:22<00:00,  3.51it/s]
# Predict on Task: sc, Dataset: sst2
# Processing sst2:  55% 275/500 [01:22<01:00,  3.70it/s]The server had an error while processing your request. Sorry about that! {
#   "error": {
#     "message": "The server had an error while processing your request. Sorry about that!",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error while processing your request. Sorry about that!', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Sat, 06 Dec 2025 05:00:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '175', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-ctnkhgdx77datjx4gmdezlio', 'openai-processing-ms': '90121', 'openai-project': 'proj_QL16vc0dqqH0F72FlTTb8pYm', 'openai-version': '2020-10-01', 'x-envoy-upstream-service-time': '90141', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '7806', 'x-ratelimit-remaining-tokens': '199932', 'x-ratelimit-reset-requests': '5h15m55.315s', 'x-ratelimit-reset-tokens': '20ms', 'x-request-id': 'req_f90ee94966d54a2c8f3a50558e837a24', 'x-openai-proxy-wasm': 'v0.1', 'cf-cache-status': 'DYNAMIC', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '9a9935dc5914d650-IAD', 'alt-svc': 'h3=":443"; ma=86400'}
# Retrying API call. Attempt #2, f<RetryCallState 136062751622304: attempt #2; slept for 10.0; last result: none yet>
# Processing sst2: 100% 500/500 [04:04<00:00,  2.05it/s]
# Predict on Task: sc, Dataset: sst5
# Processing sst5: 100% 500/500 [02:20<00:00,  3.57it/s]
# Predict on Task: sc, Dataset: twitter
# Processing twitter: 100% 500/500 [02:12<00:00,  3.76it/s]
# Predict on Task: sc, Dataset: yelp2
# Processing yelp2: 100% 500/500 [02:12<00:00,  3.76it/s]
# Predict on Task: sc, Dataset: yelp5
# Processing yelp5: 100% 500/500 [02:19<00:00,  3.57it/s]
# Predict on Task: mast, Dataset: compsent19
# Processing compsent19: 100% 314/314 [01:25<00:00,  3.67it/s]
# Predict on Task: mast, Dataset: emotion
# Processing emotion: 100% 500/500 [02:15<00:00,  3.70it/s]
# Predict on Task: mast, Dataset: hate
# Processing hate: 100% 500/500 [02:14<00:00,  3.71it/s]
# Predict on Task: mast, Dataset: implicit
# Processing implicit: 100% 442/442 [01:59<00:00,  3.71it/s]
# Predict on Task: mast, Dataset: irony
# Processing irony: 100% 500/500 [02:24<00:00,  3.45it/s]
# Predict on Task: mast, Dataset: offensive
# Processing offensive: 100% 500/500 [02:29<00:00,  3.35it/s]
# Predict on Task: mast, Dataset: stance
# Processing stance: 100% 500/500 [02:32<00:00,  3.28it/s]
# Predict on Task: absa, Dataset: asqp_rest15
# Processing asqp_rest15: 100% 500/500 [03:50<00:00,  2.17it/s]
# Predict on Task: absa, Dataset: asqp_rest16
# Processing asqp_rest16: 100% 500/500 [03:57<00:00,  2.11it/s]
# Predict on Task: absa, Dataset: aste_laptop14
# Processing aste_laptop14: 100% 328/328 [02:33<00:00,  2.13it/s]
# Predict on Task: absa, Dataset: aste_rest14
# Processing aste_rest14: 100% 492/492 [04:08<00:00,  1.98it/s]
# Predict on Task: absa, Dataset: aste_rest15
# Processing aste_rest15: 100% 322/322 [02:41<00:00,  1.99it/s]
# Predict on Task: absa, Dataset: aste_rest16
# Processing aste_rest16: 100% 326/326 [02:53<00:00,  1.88it/s]
# Predict on Task: absa, Dataset: uabsa_laptop14
# Processing uabsa_laptop14:  38% 190/500 [01:05<02:02,  2.53it/s]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741986000: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741986000: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  38% 191/500 [01:26<33:11,  6.45s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741982592: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  39% 194/500 [01:37<19:57,  3.91s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741977600: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741977600: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  39% 195/500 [01:57<45:19,  8.92s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741986672: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  40% 198/500 [02:08<23:41,  4.71s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741983552: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741983552: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  40% 201/500 [02:29<23:38,  4.74s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741975152: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741975152: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062741975152: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  41% 204/500 [03:00<31:00,  6.29s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741979280: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741979280: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  42% 208/500 [03:22<18:34,  3.82s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741978704: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741978704: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062741978704: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #5, f<RetryCallState 136062741978704: attempt #5; slept for 40.0; last result: none yet>
# Processing uabsa_laptop14:  42% 212/500 [04:03<25:24,  5.29s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741972704: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741972704: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062741972704: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  43% 215/500 [04:34<30:43,  6.47s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741977552: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741977552: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  43% 216/500 [04:55<50:24, 10.65s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741984512: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  44% 218/500 [05:05<35:14,  7.50s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741971072: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741971072: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  44% 221/500 [05:27<27:04,  5.82s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741981776: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741981776: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  44% 222/500 [05:48<47:58, 10.35s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741984080: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  45% 223/500 [05:58<47:48, 10.36s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741983504: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  45% 226/500 [06:09<24:01,  5.26s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741984176: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741984176: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  46% 228/500 [06:30<31:39,  6.98s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741975296: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741975296: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  46% 230/500 [06:51<35:07,  7.81s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741982784: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741982784: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  47% 235/500 [07:12<13:24,  3.03s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741974096: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062741974096: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062741974096: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #5, f<RetryCallState 136062741974096: attempt #5; slept for 40.0; last result: none yet>
# Processing uabsa_laptop14:  47% 237/500 [07:53<44:21, 10.12s/it]  Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062741974720: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  48% 238/500 [08:04<44:25, 10.17s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751058992: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  48% 241/500 [08:15<22:13,  5.15s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751049200: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751049200: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751049200: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  49% 243/500 [08:46<38:59,  9.10s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751062304: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  49% 245/500 [08:56<28:35,  6.73s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751062448: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751062448: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  49% 247/500 [09:17<32:18,  7.66s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751059520: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751059520: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  50% 249/500 [09:38<34:01,  8.14s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751052800: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  50% 251/500 [09:49<25:54,  6.24s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751055632: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751055632: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  50% 252/500 [10:09<43:24, 10.50s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751050208: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  51% 253/500 [10:19<43:02, 10.46s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751053184: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  52% 258/500 [10:31<11:06,  2.76s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751060096: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751060096: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751060096: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #5, f<RetryCallState 136062751060096: attempt #5; slept for 40.0; last result: none yet>
# Processing uabsa_laptop14:  52% 261/500 [11:13<28:40,  7.20s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751047856: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751047856: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  53% 263/500 [11:33<31:16,  7.92s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751054576: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751054576: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  53% 266/500 [11:55<23:03,  5.91s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751054672: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751054672: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  53% 267/500 [12:15<39:57, 10.29s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751058608: attempt #2; slept for 10.0; last result: none yet>
# Processing uabsa_laptop14:  54% 269/500 [12:26<28:36,  7.43s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751056352: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751056352: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  54% 272/500 [12:47<21:48,  5.74s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751061152: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751061152: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  55% 274/500 [13:09<27:47,  7.38s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751062064: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751062064: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  55% 277/500 [13:30<21:01,  5.66s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751052608: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751052608: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  56% 279/500 [13:50<26:20,  7.15s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751061584: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751061584: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  56% 281/500 [14:11<28:56,  7.93s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751062400: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751062400: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  57% 285/500 [14:33<15:11,  4.24s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751057696: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751057696: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751057696: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  57% 287/500 [15:04<30:24,  8.57s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751057984: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751057984: attempt #3; slept for 20.0; last result: none yet>
# Processing uabsa_laptop14:  58% 291/500 [15:25<15:09,  4.35s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751058512: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751058512: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751058512: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  59% 295/500 [15:57<15:17,  4.48s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751052512: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751052512: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751052512: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  60% 299/500 [16:28<14:51,  4.43s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751058944: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751058944: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751058944: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #5, f<RetryCallState 136062751058944: attempt #5; slept for 40.0; last result: none yet>
# Processing uabsa_laptop14:  61% 304/500 [17:10<12:42,  3.89s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751727904: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751727904: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751727904: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #5, f<RetryCallState 136062751727904: attempt #5; slept for 40.0; last result: none yet>
# Processing uabsa_laptop14:  62% 308/500 [17:51<17:01,  5.32s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751731168: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751731168: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751731168: attempt #4; slept for 30.0; last result: none yet>
# Processing uabsa_laptop14:  63% 313/500 [18:23<10:23,  3.33s/it]Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #2, f<RetryCallState 136062751724928: attempt #2; slept for 10.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #3, f<RetryCallState 136062751724928: attempt #3; slept for 20.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Retrying API call. Attempt #4, f<RetryCallState 136062751724928: attempt #4; slept for 30.0; last result: none yet>
# Rate limit reached for gpt-3.5-turbo in organization org-yhYw4286Nxo4nYR9CrMStOvH on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Processing uabsa_laptop14:  63% 313/500 [18:56<11:18,  3.63s/it]
# Traceback (most recent call last):
#   File "/content/LLM-Sentiment/predict.py", line 377, in process_dataset
#     predictions = list(tqdm(executor.map(parallel_call, prompt_args), total=len(prompt_args), desc=f"Processing {dataset}"))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 451, in result
#     self._condition.wait(timeout)
#   File "/usr/lib/python3.12/threading.py", line 355, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/LLM-Sentiment/predict.py", line 491, in <module>
#     main()
#   File "/content/LLM-Sentiment/predict.py", line 488, in main
#     process_task(args, task, api_key, selected_datasets, ignored_datasets)
#   File "/content/LLM-Sentiment/predict.py", line 464, in process_task
#     prompt_sample = process_dataset(task, dataset.name, file_path, output_dataset_folder, api_key, setting, num_workers, train_path, shots, args=args)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LLM-Sentiment/predict.py", line 376, in process_dataset
#     with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 647, in __exit__
#     self.shutdown(wait=True)
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 239, in shutdown
#     t.join()
#   File "/usr/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# Run the evaluation script to compute accuracy/F1 metrics on all tasks and datasets
# %cd /content/LLM-Sentiment
# !bash script/eval_zero_shot.sh
# Out:
# /content/LLM-Sentiment
# ----------------------------------------------------------------------------------------------------
# Gold:
# neutral: 132 (26.40%)
# positive: 269 (53.80%)
# negative: 99 (19.80%)
# Pred:
# positive: 369 (73.80%)
# neutral: 17 (3.40%)
# negative: 114 (22.80%)
# Accuracy score for asc_lap14 = 0.74
# ----------------------------------------------------------------------------------------------------
# Gold:
# positive: 328 (65.60%)
# negative: 92 (18.40%)
# neutral: 80 (16.00%)
# Pred:
# positive: 392 (78.40%)
# negative: 99 (19.80%)
# neutral: 9 (1.80%)
# Accuracy score for asc_rest14 = 0.824
# ----------------------------------------------------------------------------------------------------
# Gold:
# positive: 266 (53.20%)
# negative: 234 (46.80%)
# Pred:
# positive: 254 (50.80%)
# negative: 246 (49.20%)
# Accuracy score for imdb = 0.956
# ----------------------------------------------------------------------------------------------------
# Gold:
# negative: 248 (49.60%)
# positive: 252 (50.40%)
# Pred:
# positive: 249 (49.80%)
# negative: 249 (49.80%)
# neutral: 2 (0.40%)
# Accuracy score for mr = 0.902
# ----------------------------------------------------------------------------------------------------
# Gold:
# negative: 257 (51.40%)
# positive: 243 (48.60%)
# Pred:
# negative: 244 (48.80%)
# positive: 255 (51.00%)
# neutral: 1 (0.20%)
# Accuracy score for sst2 = 0.936
# ----------------------------------------------------------------------------------------------------
# Gold:
# very positive: 94 (18.80%)
# very negative: 55 (11.00%)
# negative: 140 (28.00%)
# positive: 111 (22.20%)
# neutral: 100 (20.00%)
# Pred:
# positive: 236 (47.20%)
# negative: 200 (40.00%)
# neutral: 47 (9.40%)
# very negative: 10 (2.00%)
# very positive: 7 (1.40%)
# Accuracy score for sst5 = 0.478
# ----------------------------------------------------------------------------------------------------
# Gold:
# neutral: 227 (45.40%)
# positive: 115 (23.00%)
# negative: 158 (31.60%)
# Pred:
# negative: 212 (42.40%)
# positive: 192 (38.40%)
# neutral: 96 (19.20%)
# Accuracy score for twitter = 0.632
# ----------------------------------------------------------------------------------------------------
# Gold:
# negative: 240 (48.00%)
# positive: 260 (52.00%)
# Pred:
# negative: 241 (48.20%)
# positive: 259 (51.80%)
# Accuracy score for yelp2 = 0.978
# ----------------------------------------------------------------------------------------------------
# Gold:
# very positive: 93 (18.60%)
# very negative: 108 (21.60%)
# positive: 115 (23.00%)
# negative: 93 (18.60%)
# neutral: 91 (18.20%)
# Pred:
# positive: 199 (39.80%)
# very negative: 34 (6.80%)
# negative: 209 (41.80%)
# neutral: 9 (1.80%)
# very positive: 49 (9.80%)
# Accuracy score for yelp5 = 0.514
# ----------------------------------------------------------------------------------------------------
# Gold:
# better: 232 (73.89%)
# worse: 82 (26.11%)
# Pred:
# better: 260 (82.80%)
# worse: 53 (16.88%)
# same: 1 (0.32%)
# Accuracy score for compsent19 = 0.7898089171974523
# ----------------------------------------------------------------------------------------------------
# Gold:
# sadness: 131 (26.20%)
# anger: 193 (38.60%)
# joy: 127 (25.40%)
# optimism: 49 (9.80%)
# Pred:
# sadness: 144 (28.80%)
# anger: 153 (30.60%)
# optimism: 48 (9.60%)
# joy: 152 (30.40%)
# fear: 3 (0.60%)
# Macro F1 score for emotion = 0.7534080549561
# ----------------------------------------------------------------------------------------------------
# Gold:
# hate: 215 (43.00%)
# non-hate: 285 (57.00%)
# Pred:
# hate: 434 (86.80%)
# non-hate: 66 (13.20%)
# Macro F1 score for hate = 0.49297406924525566
# ----------------------------------------------------------------------------------------------------
# Gold:
# negative: 82 (18.55%)
# neutral: 248 (56.11%)
# positive: 112 (25.34%)
# Pred:
# negative: 115 (26.02%)
# positive: 309 (69.91%)
# neutral: 18 (4.07%)
# Accuracy score for implicit = 0.4298642533936652
# ----------------------------------------------------------------------------------------------------
# Gold:
# irony: 209 (41.80%)
# non_irony: 291 (58.20%)
# Pred:
# irony: 387 (77.40%)
# non_irony: 113 (22.60%)
# Irony F1 score for irony = 0.697986577181208
# ----------------------------------------------------------------------------------------------------
# Gold:
# non-offensive: 360 (72.00%)
# offensive: 140 (28.00%)
# Pred:
# offensive: 326 (65.20%)
# non-offensive: 174 (34.80%)
# Macro F1 score for offensive = 0.6142161354101365
# ----------------------------------------------------------------------------------------------------
# Gold:
# none: 96 (19.20%)
# against: 279 (55.80%)
# favor: 125 (25.00%)
# Pred:
# none: 117 (23.40%)
# against: 189 (37.80%)
# favor: 194 (38.80%)
# Macro F1 (W/T None) score for stance = 0.4942193821504166
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for asqp_rest15 = 0.048072061613145735
# 26 ill-formed outputs
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for asqp_rest16 = 0.07185624104847196
# 27 ill-formed outputs
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for aste_laptop14 = 0.26272573054740866
# 1 ill-formed outputs
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for aste_rest14 = 0.41940080602974994
# 2 ill-formed outputs
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for aste_rest15 = 0.35888496856114616
# ----------------------------------------------------------------------------------------------------
# Micro_F1 score for aste_rest16 = 0.43537410037774177
# 3 ill-formed outputs
# ----------------------------------------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/LLM-Sentiment/evaluate.py", line 227, in <module>
#     main()
#   File "/content/LLM-Sentiment/evaluate.py", line 219, in main
#     metric_dict[dataset.name] = process_file(task, dataset.name, dataset.path)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LLM-Sentiment/evaluate.py", line 173, in process_file
#     df = pd.read_csv(pred_path)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#                    ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
#              ^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/zero-shot/model_chat/seed_42/absa/uabsa_laptop14/prediction.csv'
